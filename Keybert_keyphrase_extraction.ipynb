# %%
pip install keybert
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 2.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 50.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 49.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 22.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 78.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 60.3 MB/s eta 0:00:00
# ...
#   Created wheel for keybert: filename=keybert-0.7.0-py3-none-any.whl size=23776 sha256=db25c19c1794bde296fca3f82847a45b1ea86fafabefec3c65c1c1f0098ef39c
#   Stored in directory: /root/.cache/pip/wheels/66/8d/e6/b0e2f8d883b0fd51819226f67ad9843e04913ce4a97241ff4b
# ...

# %%
from keybert import KeyBERT

doc = """
          How wonderful is the living world ! The wide range of living types is amazing.
          The extraordinary habitats in which we find living organisms, be it cold mountains,
          deciduous forests, oceans, fresh water lakes, deserts or hot springs, leave us speechless.
          The beauty of a galloping horse, of the migrating birds, the valley of flowers or the attacking
          shark evokes awe and a deep sense of wonder. The ecological conflict and cooperation among members
          of a population and among populations of a community or even the molecular traffic inside a cell
          make us deeply reflect on – what indeed is life? This question has two implicit questions within it.
          The first is a technical one and seeks answer to what living is as opposed to the non-living, and
          the second is a philosophical one, and seeks answer to what the purpose of life is. As scientists,
          we shall not attempt answering the second question. We will try to reflect on – what is living?
          DIVERSITY IN THE LIVING WORLD If you look around you will see a large variety of living organisms,
          be it potted plants, insects, birds, your pets or other animals and plants
      """

# %%
kw_model = KeyBERT()
keywords = kw_model.extract_keywords(doc)

# %%
kw_model.extract_keywords(doc, keyphrase_ngram_range=(1, 1), stop_words=None)
# Out:
# [('living', 0.5474),
#  ('life', 0.5233),
#  ('ecological', 0.5057),
#  ('organisms', 0.4877),
#  ('habitats', 0.3652)]

# %%
kw_model.extract_keywords(doc, keyphrase_ngram_range=(1, 2), stop_words=None)
# Out:
# [('what living', 0.6465),
#  ('living organisms', 0.6302),
#  ('the living', 0.6051),
#  ('is living', 0.5971),
#  ('living world', 0.5938)]

# %%
kw_model.extract_keywords(doc, keyphrase_ngram_range=(3, 3), stop_words='english', use_maxsum=True, nr_candidates=20, top_n=5 )
# Out:
# [('answer living opposed', 0.4453),
#  ('life scientists shall', 0.4467),
#  ('living types amazing', 0.4915),
#  ('extraordinary habitats living', 0.5182),
#  ('answer purpose life', 0.5662)]

# %%
kw_model.extract_keywords(doc, keyphrase_ngram_range=(3, 3), stop_words='english', use_mmr=True, diversity=0.2)
# Out:
# [('seeks answer living', 0.6105),
#  ('variety living organisms', 0.5647),
#  ('wonderful living world', 0.5646),
#  ('reflect living diversity', 0.5479),
#  ('sense wonder ecological', 0.5401)]

# %%
kw_model.extract_keywords(doc, keyphrase_ngram_range=(3, 3), stop_words='english', use_mmr=True, diversity=0.7)
# Out:
# [('seeks answer living', 0.6105),
#  ('populations community molecular', 0.3276),
#  ('oceans fresh water', 0.2324),
#  ('plants insects birds', 0.1933),
#  ('types amazing extraordinary', 0.1725)]

# %%
kw_model.extract_keywords(doc, keyphrase_ngram_range=(3, 5), stop_words='english', use_mmr=True, diversity=0.7)
# Out:
# [('seeks answer living', 0.6105),
#  ('insects birds pets animals plants', 0.215),
#  ('molecular traffic inside cell make', 0.1938),
#  ('types amazing extraordinary', 0.1725),
#  ('cold mountains deciduous', 0.1642)]

# %%
import json
with open("/content/drive/MyDrive/Datasetnew/Reviewed.json","r", encoding = "utf-8") as f:
    data = json.load(f)
all_content_list = []
for subject in data["subjects"]:
    for lesson in subject["lessons"]:
        all_content_list.append("whole_lesson_content")

# %%
import json

# %%
with open("/content/drive/MyDrive/Datasetnew/Reviewed.json","r", encoding="utf-8") as f:
  data = json.load(f)
  all_content_list = []
for subject in data["subjects"]:
    for lesson in subject["lessons"]:
        all_content_list.append(lesson["whole_lesson_content"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-94447a007be7> in <cell line: 4>()
#       4 for subject in data["subjects"]:
#       5     for lesson in subject["lessons"]:
# ----> 6         all_content_list.append(lesson["whole_lesson_content"])
#
# KeyError: 'whole_lesson_content'

# %%
pip install keybert

# %%
from keybert import KeyBERT

doc = """
         /content/drive/MyDrive/Datasetnew/Reviewed.json
      """

# %%
kw_model = KeyBERT()
keywords = kw_model.extract_keywords(doc)

# %%
kw_model.extract_keywords(doc, keyphrase_ngram_range=(1, 1), stop_words=None)
# Out:
# [('json', 0.4814),
#  ('datasetnew', 0.4425),
#  ('mydrive', 0.3865),
#  ('reviewed', 0.3619),
#  ('drive', 0.2765)]
